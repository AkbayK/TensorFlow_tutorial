# %%
# !conda remove wrapt --yes
# Out:
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3
#
#   removed specs:
#     - wrapt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.8.0       |           py37_0         147 KB
#     cffi-1.12.3                |   py37h7a1dbc1_0         225 KB
#     chardet-3.0.4              |        py37_1003         192 KB
#     filelock-3.0.12            |             py_0          12 KB
#     glob2-0.7                  |             py_0          14 KB
#     idna-2.8                   |           py37_0         101 KB
#     json5-0.8.5                |             py_0          25 KB
#     jupyter_client-5.3.3       |           py37_1         162 KB
#     jupyterlab-1.1.4           |     pyhf63ae98_0        11.7 MB
#     jupyterlab_server-1.0.6    |             py_0          26 KB
#     libtiff-4.0.10             |       hb898794_2         1.1 MB
#     menuinst-1.4.16            |   py37he774522_0         227 KB
#     pillow-6.1.0               |   py37hdc69c19_0         710 KB
#     pkginfo-1.5.0.1            |           py37_0          60 KB
#     psutil-5.6.3               |   py37he774522_0         350 KB
#     pycparser-2.19             |           py37_0         173 KB
#     pyopenssl-19.0.0           |           py37_0          82 KB
#     pyrsistent-0.15.4          |   py37he774522_0          95 KB
#     pysocks-1.7.1              |           py37_0          30 KB
#     pyyaml-5.1.2               |   py37he774522_0         163 KB
#     qtpy-1.9.0                 |             py_0          39 KB
#     requests-2.22.0            |           py37_0          90 KB
#     soupsieve-1.9.3            |           py37_0          60 KB
#     tqdm-4.36.1                |             py_0          50 KB
#     urllib3-1.24.2             |           py37_0         153 KB
#     win_inet_pton-1.1.0        |           py37_0           9 KB
#     xz-5.2.4                   |       h2fa13f4_4         812 KB
#     zstd-1.3.7                 |       h508b16e_0         536 KB
#     ------------------------------------------------------------
#                                            Total:        17.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   json5              pkgs/main/noarch::json5-0.8.5-py_0
#   jupyterlab_server  pkgs/main/noarch::jupyterlab_server-1.0.6-py_0
#   pyrsistent         pkgs/main/win-64::pyrsistent-0.15.4-py37he774522_0
#   soupsieve          pkgs/main/win-64::soupsieve-1.9.3-py37_0
#   xz                 pkgs/main/win-64::xz-5.2.4-h2fa13f4_4
#   zstd               pkgs/main/win-64::zstd-1.3.7-h508b16e_0
#
# The following packages will be REMOVED:
#
#   alabaster-0.7.11-py37_0
#   anaconda-5.3.1-py37_0
#   anaconda-project-0.8.2-py37_0
#   appdirs-1.4.3-py37h28b3542_0
#   astroid-2.0.4-py37_0
#   astropy-3.0.4-py37hfa6e2cd_0
#   atomicwrites-1.2.1-py37_0
#   automat-0.7.0-py37_0
#   babel-2.6.0-py37_0
#   backports-1.0-py37_1
#   backports.shutil_get_terminal_size-1.0.0-py37_2
#   bitarray-0.8.3-py37hfa6e2cd_0
#   bkcharts-0.2-py37_0
#   blas-1.0-mkl
#   blaze-0.11.3-py37_0
#   blosc-1.14.4-he51fdeb_0
#   bokeh-0.13.0-py37_0
#   boto-2.49.0-py37_0
#   bottleneck-1.2.1-py37h452e1ab_1
#   bzip2-1.0.6-hfa6e2cd_5
#   click-6.7-py37_0
#   cloudpickle-0.5.5-py37_0
#   comtypes-1.1.7-py37_0
#   constantly-15.1.0-py37h28b3542_0
#   contextlib2-0.5.5-py37_0
#   curl-7.65.3-h2a8f88b_0
#   cycler-0.10.0-py37_0
#   cython-0.28.5-py37h6538335_0
#   cytoolz-0.9.0.1-py37hfa6e2cd_1
#   dask-0.19.1-py37_0
#   dask-core-0.19.1-py37_0
#   datashape-0.5.4-py37_1
#   distributed-1.23.1-py37_0
#   docutils-0.14-py37_0
#   et_xmlfile-1.0.1-py37_0
#   fastcache-1.0.2-py37hfa6e2cd_2
#   flask-1.0.2-py37_1
#   flask-cors-3.0.6-py37_0
#   get_terminal_size-1.0.0-h38e98db_0
#   gevent-1.3.6-py37hfa6e2cd_0
#   greenlet-0.4.15-py37hfa6e2cd_0
#   h5py-2.8.0-py37h3bdd7fb_2
#   hdf5-1.10.2-hac2f561_1
#   heapdict-1.0.0-py37_2
#   html5lib-1.0.1-py37_0
#   hyperlink-18.0.0-py37_0
#   icc_rt-2017.0.4-h97af966_0
#   imageio-2.4.1-py37_0
#   imagesize-1.1.0-py37_0
#   incremental-17.5.0-py37_0
#   intel-openmp-2019.0-118
#   isort-4.3.4-py37_0
#   itsdangerous-0.24-py37_1
#   jdcal-1.4-py37_0
#   jupyter-1.0.0-py37_7
#   jupyter_console-5.2.0-py37_1
#   jupyterlab_launcher-0.13.1-py37_0
#   keyring-13.2.1-py37_0
#   kiwisolver-1.0.1-py37h6538335_0
#   krb5-1.16.1-hc04afaa_7
#   lazy-object-proxy-1.3.1-py37hfa6e2cd_2
#   libcurl-7.65.3-h2a8f88b_0
#   libiconv-1.15-h1df5818_7
#   libssh2-1.8.2-h7a1dbc1_0
#   libxml2-2.9.8-hadb2253_1
#   libxslt-1.1.32-hf6f1972_0
#   llvmlite-0.24.0-py37h6538335_0
#   locket-0.2.0-py37_1
#   lxml-4.2.5-py37hef2cd61_0
#   lzo-2.10-h6df0209_2
#   matplotlib-2.2.3-py37hd159220_0
#   mccabe-0.6.1-py37_1
#   mkl-2019.0-118
#   mkl-service-1.1.2-py37hb217b18_5
#   mkl_fft-1.0.4-py37h1e22a9b_1
#   mkl_random-1.0.1-py37h77b88f5_1
#   more-itertools-4.3.0-py37_0
#   mpmath-1.0.0-py37_2
#   msgpack-python-0.5.6-py37he980bc4_1
#   multipledispatch-0.6.0-py37_0
#   networkx-2.1-py37_0
#   nltk-3.3.0-py37_0
#   nose-1.3.7-py37_2
#   numba-0.39.0-py37h830ac7b_0
#   numexpr-2.6.8-py37h9ef55f4_0
#   numpy-1.15.1-py37ha559c80_0
#   numpy-base-1.15.1-py37h8128ebf_0
#   numpydoc-0.8.0-py37_0
#   odo-0.5.1-py37_0
#   openpyxl-2.5.6-py37_0
#   packaging-17.1-py37_0
#   pandas-0.23.4-py37h830ac7b_0
#   partd-0.3.8-py37_0
#   path.py-11.1.0-py37_0
#   pathlib2-2.3.2-py37_0
#   patsy-0.5.0-py37_0
#   pep8-1.7.1-py37_0
#   pluggy-0.7.1-py37h28b3542_0
#   ply-3.11-py37_0
#   py-1.6.0-py37_0
#   pyasn1-0.4.4-py37h28b3542_0
#   pyasn1-modules-0.2.2-py37_0
#   pycodestyle-2.4.0-py37_0
#   pycrypto-2.6.1-py37hfa6e2cd_9
#   pycurl-7.43.0.3-py37h7a1dbc1_0
#   pyflakes-2.0.0-py37_0
#   pylint-2.1.1-py37_0
#   pyodbc-4.0.24-py37h6538335_0
#   pyparsing-2.2.0-py37_1
#   pytables-3.4.4-py37he6f6034_0
#   pytest-3.8.0-py37_0
#   pytest-arraydiff-0.2-py37h39e3cac_0
#   pytest-astropy-0.4.0-py37_0
#   pytest-doctestplus-0.1.3-py37_0
#   pytest-openfiles-0.3.0-py37_0
#   pytest-remotedata-0.3.0-py37_0
#   pywavelets-1.0.0-py37h452e1ab_0
#   qtawesome-0.4.4-py37_0
#   qtconsole-4.4.1-py37_0
#   rope-0.11.0-py37_0
#   scikit-image-0.14.0-py37h6538335_1
#   scikit-learn-0.19.2-py37heebcf9a_0
#   scipy-1.1.0-py37h4f6bf74_1
#   seaborn-0.9.0-py37_0
#   service_identity-17.0.0-py37h28b3542_0
#   simplegeneric-0.8.1-py37_2
#   singledispatch-3.4.0.3-py37_0
#   snappy-1.1.7-h777316e_3
#   snowballstemmer-1.2.1-py37_0
#   sortedcollections-1.0.1-py37_0
#   sortedcontainers-2.0.5-py37_0
#   sphinx-1.7.9-py37_0
#   sphinxcontrib-1.0-py37_1
#   sphinxcontrib-websupport-1.1.0-py37_1
#   spyder-3.3.1-py37_1
#   spyder-kernels-0.2.6-py37_0
#   sqlalchemy-1.2.11-py37hfa6e2cd_0
#   statsmodels-0.9.0-py37h452e1ab_0
#   sympy-1.1.1-py37_0
#   tblib-1.3.2-py37_0
#   toolz-0.9.0-py37_0
#   twisted-18.7.0-py37hfa6e2cd_1
#   unicodecsv-0.14.1-py37_0
#   werkzeug-0.14.1-py37_0
#   win_unicode_console-0.5-py37_0
#   wrapt-1.10.11-py37hfa6e2cd_2
#   xlrd-1.1.0-py37_1
#   xlsxwriter-1.1.0-py37_0
#   xlwings-0.11.8-py37_0
#   xlwt-1.3.0-py37_0
#   zict-0.1.3-py37_0
#   zope-1.0-py37_1
#   zope.interface-4.5.0-py37hfa6e2cd_0
#
# The following packages will be UPDATED:
#
#   attrs                               18.2.0-py37h28b3542_0 --> 19.1.0-py37_1
#   beautifulsoup4                               4.6.3-py37_0 --> 4.8.0-py37_0
#   bleach                                       2.1.4-py37_0 --> 3.1.0-py37_0
#   cffi                                1.11.5-py37h74b6da3_1 --> 1.12.3-py37h7a1dbc1_0
#   chardet                                      3.0.4-py37_1 --> 3.0.4-py37_1003
#   colorama                                     0.3.9-py37_0 --> 0.4.1-py37_0
#   decorator                                    4.3.0-py37_0 --> 4.4.0-py37_1
#   defusedxml         pkgs/main/win-64::defusedxml-0.5.0-py~ --> pkgs/main/noarch::defusedxml-0.6.0-py_0
#   entrypoints                                  0.2.3-py37_2 --> 0.3-py37_0
#   filelock           pkgs/main/win-64::filelock-3.0.8-py37~ --> pkgs/main/noarch::filelock-3.0.12-py_0
#   glob2                  pkgs/main/win-64::glob2-0.6-py37_0 --> pkgs/main/noarch::glob2-0.7-py_0
#   idna                                           2.7-py37_0 --> 2.8-py37_0
#   ipykernel                                   4.10.0-py37_0 --> 5.1.2-py37h39e3cac_0
#   ipython                                      6.5.0-py37_0 --> 7.8.0-py37h39e3cac_0
#   ipywidgets         pkgs/main/win-64::ipywidgets-7.4.1-py~ --> pkgs/main/noarch::ipywidgets-7.5.1-py_0
#   jedi                                        0.12.1-py37_0 --> 0.15.1-py37_0
#   jinja2                                        2.10-py37_0 --> 2.10.1-py37_0
#   jsonschema                                   2.6.0-py37_0 --> 3.0.2-py37_0
#   jupyter_client                               5.2.3-py37_0 --> 5.3.3-py37_1
#   jupyter_core       pkgs/main/win-64::jupyter_core-4.4.0-~ --> pkgs/main/noarch::jupyter_core-4.5.0-py_0
#   jupyterlab         pkgs/main/win-64::jupyterlab-0.34.9-p~ --> pkgs/main/noarch::jupyterlab-1.1.4-pyhf63ae98_0
#   libtiff                                  4.0.9-h36446d0_2 --> 4.0.10-hb898794_2
#   markupsafe                             1.0-py37hfa6e2cd_1 --> 1.1.1-py37he774522_0
#   menuinst                            1.4.14-py37hfa6e2cd_0 --> 1.4.16-py37he774522_0
#   mistune                              0.8.3-py37hfa6e2cd_1 --> 0.8.4-py37he774522_0
#   nbconvert                                    5.4.0-py37_1 --> 5.6.0-py37_1
#   notebook                                     5.6.0-py37_0 --> 6.0.1-py37_0
#   pandoc                                1.19.2.1-hb2460c7_1 --> 2.2.3.2-0
#   parso                pkgs/main/win-64::parso-0.3.1-py37_0 --> pkgs/main/noarch::parso-0.5.1-py_0
#   pickleshare                                  0.7.4-py37_0 --> 0.7.5-py37_0
#   pillow                               5.2.0-py37h08bbbbd_0 --> 6.1.0-py37hdc69c19_0
#   pip                                         10.0.1-py37_0 --> 19.2.3-py37_0
#   pkginfo                                      1.4.2-py37_1 --> 1.5.0.1-py37_0
#   prometheus_client  pkgs/main/win-64::prometheus_client-0~ --> pkgs/main/noarch::prometheus_client-0.7.1-py_0
#   prompt_toolkit                              1.0.15-py37_0 --> 2.0.9-py37_0
#   psutil                               5.4.7-py37hfa6e2cd_0 --> 5.6.3-py37he774522_0
#   pycparser                                     2.18-py37_1 --> 2.19-py37_0
#   pygments           pkgs/main/win-64::pygments-2.2.0-py37~ --> pkgs/main/noarch::pygments-2.4.2-py_0
#   pyopenssl                                   18.0.0-py37_0 --> 19.0.0-py37_0
#   pysocks                                      1.6.8-py37_0 --> 1.7.1-py37_0
#   python-dateutil                              2.7.3-py37_0 --> 2.8.0-py37_0
#   pytz                 pkgs/main/win-64::pytz-2018.5-py37_0 --> pkgs/main/noarch::pytz-2019.2-py_0
#   pywinpty                                     0.5.4-py37_0 --> 0.5.5-py37_1000
#   pyyaml                                3.13-py37hfa6e2cd_0 --> 5.1.2-py37he774522_0
#   pyzmq                               17.1.2-py37hfa6e2cd_0 --> 18.1.0-py37ha925a31_0
#   qtpy                  pkgs/main/win-64::qtpy-1.5.0-py37_0 --> pkgs/main/noarch::qtpy-1.9.0-py_0
#   requests                                    2.19.1-py37_0 --> 2.22.0-py37_0
#   setuptools                                  40.2.0-py37_0 --> 41.2.0-py37_0
#   six                                         1.11.0-py37_1 --> 1.12.0-py37_0
#   terminado                                    0.8.1-py37_1 --> 0.8.2-py37_0
#   testpath                                     0.3.1-py37_0 --> 0.4.2-py37_0
#   tornado                                5.1-py37hfa6e2cd_0 --> 6.0.3-py37he774522_0
#   tqdm               pkgs/main/win-64::tqdm-4.26.0-py37h28~ --> pkgs/main/noarch::tqdm-4.36.1-py_0
#   urllib3                                       1.23-py37_0 --> 1.24.2-py37_0
#   wheel                                       0.31.1-py37_0 --> 0.33.6-py37_0
#   widgetsnbextension                           3.4.1-py37_0 --> 3.5.1-py37_0
#   win_inet_pton                                1.0.1-py37_1 --> 1.1.0-py37_0
#   zeromq                                   4.2.5-he025d50_1 --> 4.3.1-h33f27b4_3
#   zlib                                    1.2.11-h8395fce_2 --> 1.2.11-h62dcd97_3
#
#
#
# Downloading and Extracting Packages
#
# zstd-1.3.7           | 536 KB    |            |   0%
#
# beautifulsoup4-4.8.0 | 147 KB    |            |   0%
#
# pysocks-1.7.1        | 30 KB     |            |   0%
#
# pycparser-2.19       | 173 KB    |            |   0%
#
# pyyaml-5.1.2         | 163 KB    |            |   0%
#
# psutil-5.6.3         | 350 KB    |            |   0%
#
# pillow-6.1.0         | 710 KB    |            |   0%
#
# urllib3-1.24.2       | 153 KB    |            |   0%
#
# cffi-1.12.3          | 225 KB    |            |   0%
#
# win_inet_pton-1.1.0  | 9 KB      |            |   0%
#
# pyrsistent-0.15.4    | 95 KB     |            |   0%
#
# libtiff-4.0.10       | 1.1 MB    |            |   0%
#
# xz-5.2.4             | 812 KB    |            |   0%
#
# jupyter_client-5.3.3 | 162 KB    |            |   0%
#
# pyopenssl-19.0.0     | 82 KB     |            |   0%
#
# idna-2.8             | 101 KB    |            |   0%
#
# glob2-0.7            | 14 KB     |            |   0%
#
# jupyterlab_server-1. | 26 KB     |            |   0%
#
# menuinst-1.4.16      | 227 KB    |            |   0%
#
# jupyterlab-1.1.4     | 11.7 MB   |            |   0%
#
# soupsieve-1.9.3      | 60 KB     |            |   0%
#
# pkginfo-1.5.0.1      | 60 KB     |            |   0%
#
# json5-0.8.5          | 25 KB     |            |   0%
#
# requests-2.22.0      | 90 KB     |            |   0%
#
# qtpy-1.9.0           | 39 KB     |            |   0%
#
# tqdm-4.36.1          | 50 KB     |            |   0%
#
# filelock-3.0.12      | 12 KB     |            |   0%
#
# chardet-3.0.4        | 192 KB    |            |   0%
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура
# [WinError 127] Не найдена указанная процедура

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached https://files.pythonhosted.org/packages/f7/08/25e47a53692c2e0dcd2211a493ddfe9007a5cd92e175d6dffa6169a0b392/tensorflow-1.14.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: gast>=0.2.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.31.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.23.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.15.1)
# Collecting wrapt>=1.11.1 (from tensorflow)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.1.7)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (0.14.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (41.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (3.1.1)
# Requirement already satisfied: h5py in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Installing collected packages: wrapt, tensorflow
#   Found existing installation: wrapt 1.10.11
# ERROR: Cannot uninstall 'wrapt'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !pip install wrapt --upgrade --ignore-installed
# Out:
# Collecting wrapt
# Installing collected packages: wrapt
# Successfully installed wrapt-1.11.2

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached https://files.pythonhosted.org/packages/f7/08/25e47a53692c2e0dcd2211a493ddfe9007a5cd92e175d6dffa6169a0b392/tensorflow-1.14.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.23.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.11.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: gast>=0.2.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.31.1)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.1.7)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.15.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: setuptools in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from protobuf>=3.6.1->tensorflow) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (3.1.1)
# Requirement already satisfied: h5py in c:\users\kuderbekov_a\appdata\local\continuum\anaconda3\lib\site-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-1.14.0

# %%
# !pip install --upgrade numpy
# Out:
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/bd/51/7df1a3858ff0465f760b482514f1292836f8be08d84aba411b48dda72fa9/numpy-1.17.2-cp37-cp37m-win_amd64.whl (12.8MB)
# Installing collected packages: numpy
#   Found existing installation: numpy 1.15.1
#     Uninstalling numpy-1.15.1:
#       Successfully uninstalled numpy-1.15.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Отказано в доступе: 'c:\\users\\kuderbekov_a\\appdata\\local\\continuum\\anaconda3\\lib\\site-packages\\~umpy\\core\\multiarray.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import tensorflow as tf
# Out:
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kuderbekov_a\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np

# %%
pip uninstall numpy
conda install numpy

# %%
# !pip uninstall numpy
